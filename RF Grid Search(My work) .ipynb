# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first = True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion': ['squared_error', 'absolute_error'],'max_features': ['sqrt', 'log2'],'n_estimators': [10, 100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\Users\Vasanth Ravi\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}: 0.8710257167662804

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.191183      0.021729         0.008709        0.002582
# 1       0.775979      0.088000         0.029471        0.001295
# 2       0.070406      0.006034         0.006366        0.001240
# 3       0.676518      0.015259         0.026509        0.002125
# 4       0.181122      0.005571         0.006649        0.000761
# 5       1.687496      0.049334         0.026484        0.004068
# 6       0.183575      0.005705         0.008078        0.000546
# 7       1.716524      0.029123         0.025536        0.002102
#
#   param_criterion param_max_features  param_n_estimators  \
# 0   squared_error               sqrt                  10
# 1   squared_error               sqrt                 100
# 2   squared_error               log2                  10
# 3   squared_error               log2                 100
# 4  absolute_error               sqrt                  10
# 5  absolute_error               sqrt                 100
# 6  absolute_error               log2                  10
# 7  absolute_error               log2                 100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'max_features':...           0.782228
# 1  {'criterion': 'squared_error', 'max_features':...           0.808018
# 2  {'criterion': 'squared_error', 'max_features':...           0.806643
# 3  {'criterion': 'squared_error', 'max_features':...           0.811171
# 4  {'criterion': 'absolute_error', 'max_features'...           0.769964
# 5  {'criterion': 'absolute_error', 'max_features'...           0.796464
# 6  {'criterion': 'absolute_error', 'max_features'...           0.789426
# 7  {'criterion': 'absolute_error', 'max_features'...           0.804874
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.758002           0.818049           0.802251           0.749333
# 1           0.770713           0.840726           0.829142           0.760552
# 2           0.742395           0.816578           0.805348           0.747035
# 3           0.767197           0.829400           0.826678           0.758623
# 4           0.743704           0.804216           0.811311           0.734346
# 5           0.774028           0.834495           0.824101           0.761946
# 6           0.761597           0.809949           0.820660           0.746993
# 7           0.764498           0.840067           0.825232           0.762294
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.781973        0.025895                7
# 1         0.801830        0.031525                1
# 2         0.783600        0.032020                6
# 3         0.798614        0.029931                3
# 4         0.772708        0.030995                8
# 5         0.798206        0.027892                4
# 6         0.785725        0.027940                5
# 7         0.799393        0.031452                2

# %%
age_input=float(input('age'))
bmi_input=float(input('bmi'))
children_input=float(input('children'))
sex_male_input=int(input('sex_male'))
smoker_yes_input=int(input('smoker'))
# Out:
# age 32
# bmi 34.89
# children 3
# sex_male 0
# smoker 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[48165.5737303]
